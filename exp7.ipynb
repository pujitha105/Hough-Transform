# %% [markdown]
# ## exp.no 7 Hough Transform
# **Name:** k.pujitha
#
# **Reg.No:** 212223240074

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
road_image = cv2.imread('nature.jpeg')

# %%
color_image = cv2.cvtColor(road_image, cv2.COLOR_BGR2RGB)

# %%
gray_image = cv2.imread('nature.jpeg', cv2.IMREAD_GRAYSCALE)

# %%
reduce_noise = cv2.GaussianBlur(gray_image, (3,3), 0)

# %%
plt.figure(figsize=(10,10))
plt.imshow(road_image[:,:,::-1])
plt.title("Original Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(167.5), np.float64(-0.5))

# %%
gray_image = cv2.imread('nature.jpeg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(gray_image, cmap='gray')
plt.title("Gray Image")
plt.axis("off")
plt.show()

# %%
canny = cv2.Canny(gray_image, 120, 150)

# %%
plt.imshow(canny, cmap='gray')
plt.title("Canny Edge Detector")
plt.axis("off")
plt.show()

# %%
lines = cv2.HoughLinesP(canny, 1, np.pi/180, threshold=80, minLineLength=50, maxLineGap=250)

# %%
if lines is not None:
    for line in lines:
        x1, y1, x2, y2 = line[0]
        cv2.line(road_image, (x1, y1), (x2, y2), (255, 0, 0), 3)

# %%
plt.imshow(road_image)
plt.title("Result Image with Hough Lines")
plt.axis("off")
plt.show()
